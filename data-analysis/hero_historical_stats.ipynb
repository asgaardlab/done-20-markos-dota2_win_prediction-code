# %% [markdown]
# #### Notebook to compute historical stats for each hero for each Dota 2 version

# %%
import os
import json
import csv
import pandas as pd

# %%
changelog_dir = "hero_changelog/"
hero_historical_stats_dir = "hero_historical_stats/"

# %%
with open("heroes.json", 'r') as hero_file:
    heroes = json.load(hero_file) # 119 different heroes May 23rd

# %%
def get_current_stat(hero_name, name_of_stat):
    list_hero_id = list()
    for each_hero_id in heroes:
        list_hero_id.append(each_hero_id)
        
    for hero_id in list_hero_id:
        specific_hero_dict = heroes[str(hero_id)]
        if specific_hero_dict['localized_name'] == hero_name:
            stat = specific_hero_dict[name_of_stat]
            break
    
    return stat

# %%
def extract_stat(change):
    change = change.strip('[')
    change = change.strip(']')
    change = change.strip('\'')
    change = change.rstrip('\.')
    change_split = change.split(' ')
    list_values = list()
    for each in change_split:
        try:
            list_values.append(float(each))
        except:
            continue
    print(list_values)
    return list_values

# %%
all_changelog_files = os.listdir(changelog_dir)
count=0
for each_changelog_file in all_changelog_files:  # each changelog file corresponds to a hero
    print(each_changelog_file)
    hero_name = each_changelog_file.replace('_changelog_dict.csv', '')
    print(hero_name)
    
#     hero_historical_stats_df = pd.DataFrame(columns=['version', 'base_strength', 'strength_gain'])
    hero_historical_stats_df = pd.DataFrame(columns=['version', 'base_strength', 'base_agility', 'base_intelligence',
                                                     'strength_gain', 'agility_gain', 'intelligence_gain', 'base_health',
                                                     'base_health_regeneration', 'move_speed'])
    #print(hero_historical_stats_df)
    index_df = 0

    with open(changelog_dir + each_changelog_file) as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')
        line_count = 0
        use_current_stat = False
        version_changes_dict = {}
        
        ### ADD NEW HERE
        base_strength_dict = {}
        base_agility_dict = {}
        base_intelligence_dict = {}
        strength_gain_dict = {}
        agility_gain_dict = {}
        intelligence_gain_dict = {}
        base_health_dict = {}
        base_health_regeneration_dict = {}
        move_speed_dict = {}
        
        ### ADD NEW HERE
        list_of_versions = list()
        for row in csv_reader:
            version = row[0]
            changes = row[1]
            list_of_versions.append(version)
            version_changes_dict[version] = changes
            base_strength_dict[version] = -100
            base_agility_dict[version] = -100
            base_intelligence_dict[version] = -100
            strength_gain_dict[version] = -100
            agility_gain_dict[version] = -100
            intelligence_gain_dict[version] = -100
            base_health_dict[version] = -100
            base_health_regeneration_dict[version] = -100
            move_speed_dict[version] = -100
            
        # base strength
        list_versions_empty = list()
        past_value_to_add = 0
        is_past_value_to_add = False
        
        for each_key in version_changes_dict:
            version = each_key
            changes = version_changes_dict[each_key]
            changes_list = changes.split(',')
            no_related_change = True
            for each_change in changes_list:
                if "base strength from" in each_change:
                    no_related_change = False
                    list_value = extract_stat(each_change)
                    past_value = list_value[0]
                    current_value = list_value[1]
                else:
                    if is_past_value_to_add:
                        base_strength_dict[version] = past_value_to_add
            
            if no_related_change:
                list_versions_empty.append(version)
            else:
                base_strength_dict[version] = current_value
                for each_version in list_versions_empty:
                    base_strength_dict[each_version] = current_value
                list_versions_empty = list()
                past_value_to_add = past_value
                is_past_value_to_add = True
        
        for key in base_strength_dict:
            if base_strength_dict[key] == -100:
                current_stat = get_current_stat(hero_name, 'base_str')
                use_current_stat = True
                break
        
        if use_current_stat:
            for key in base_strength_dict:
                base_strength_dict[key] = current_stat
            use_current_stat = False
                
        # base agility
        list_versions_empty = list()
        past_value_to_add = 0
        is_past_value_to_add = False
        
        for each_key in version_changes_dict:
            version = each_key
            changes = version_changes_dict[each_key]
            changes_list = changes.split(',')
            no_related_change = True
            for each_change in changes_list:
                if "base agility from" in each_change:
                    no_related_change = False
                    list_value = extract_stat(each_change)
                    past_value = list_value[0]
                    current_value = list_value[1]
                else:
                    if is_past_value_to_add:
                        base_agility_dict[version] = past_value_to_add
            
            if no_related_change:
                list_versions_empty.append(version)
            else:
                base_agility_dict[version] = current_value
                for each_version in list_versions_empty:
                    base_agility_dict[each_version] = current_value
                list_versions_empty = list()
                past_value_to_add = past_value
                is_past_value_to_add = True
        
        for key in base_agility_dict:
            if base_agility_dict[key] == -100:
                current_stat = get_current_stat(hero_name, 'base_agi')
                use_current_stat = True
                break
        
        if use_current_stat:
            for key in base_agility_dict:
                base_agility_dict[key] = current_stat
            use_current_stat = False
            

        # base intelligence
        list_versions_empty = list()
        past_value_to_add = 0
        is_past_value_to_add = False
        
        for each_key in version_changes_dict:
            version = each_key
            changes = version_changes_dict[each_key]
            changes_list = changes.split(',')
            no_related_change = True
            for each_change in changes_list:
                if "base intelligence from" in each_change:
                    no_related_change = False
                    list_value = extract_stat(each_change)
                    past_value = list_value[0]
                    current_value = list_value[1]
                else:
                    if is_past_value_to_add:
                        base_intelligence_dict[version] = past_value_to_add
            
            if no_related_change:
                list_versions_empty.append(version)
            else:
                base_intelligence_dict[version] = current_value
                for each_version in list_versions_empty:
                    base_intelligence_dict[each_version] = current_value
                list_versions_empty = list()
                past_value_to_add = past_value
                is_past_value_to_add = True
        
        for key in base_intelligence_dict:
            if base_intelligence_dict[key] == -100:
                current_stat = get_current_stat(hero_name, 'base_int')
                use_current_stat = True
                break
        
        if use_current_stat:
            for key in base_intelligence_dict:
                base_intelligence_dict[key] = current_stat
            use_current_stat = False
            
            
        # strength gain        
        list_versions_empty = list()
        past_value_to_add = 0
        is_past_value_to_add = False
        
        for each_key in version_changes_dict:
            version = each_key
            changes = version_changes_dict[each_key]
            changes_list = changes.split(',')
            no_related_change = True
            for each_change in changes_list:
                if "strength gain from" in each_change:
                    no_related_change = False
                    list_value = extract_stat(each_change)
                    past_value = list_value[0]
                    current_value = list_value[1]
                else:
                    if is_past_value_to_add:
                        strength_gain_dict[version] = past_value_to_add
            
            if no_related_change:
                list_versions_empty.append(version)
            else:
                strength_gain_dict[version] = current_value
                for each_version in list_versions_empty:
                    strength_gain_dict[each_version] = current_value
                list_versions_empty = list()
                past_value_to_add = past_value
                is_past_value_to_add = True
        
        for key in strength_gain_dict:
            if strength_gain_dict[key] == -100:
                current_stat = get_current_stat(hero_name, 'str_gain')
                use_current_stat = True
                break
        
        if use_current_stat:
            for key in strength_gain_dict:
                strength_gain_dict[key] = current_stat
            use_current_stat = False

            
        # agility gain        
        list_versions_empty = list()
        past_value_to_add = 0
        is_past_value_to_add = False
        
        for each_key in version_changes_dict:
            version = each_key
            changes = version_changes_dict[each_key]
            changes_list = changes.split(',')
            no_related_change = True
            for each_change in changes_list:
                if "agility gain from" in each_change:
                    no_related_change = False
                    list_value = extract_stat(each_change)
                    past_value = list_value[0]
                    current_value = list_value[1]
                else:
                    if is_past_value_to_add:
                        agility_gain_dict[version] = past_value_to_add
            
            if no_related_change:
                list_versions_empty.append(version)
            else:
                agility_gain_dict[version] = current_value
                for each_version in list_versions_empty:
                    agility_gain_dict[each_version] = current_value
                list_versions_empty = list()
                past_value_to_add = past_value
                is_past_value_to_add = True
        
        for key in agility_gain_dict:
            if agility_gain_dict[key] == -100:
                current_stat = get_current_stat(hero_name, 'agi_gain')
                use_current_stat = True
                break
        
        if use_current_stat:
            for key in agility_gain_dict:
                agility_gain_dict[key] = current_stat
            use_current_stat = False

        # intelligence gain        
        list_versions_empty = list()
        past_value_to_add = 0
        is_past_value_to_add = False
        
        for each_key in version_changes_dict:
            version = each_key
            changes = version_changes_dict[each_key]
            changes_list = changes.split(',')
            no_related_change = True
            for each_change in changes_list:
                if "intelligence gain from" in each_change:
                    no_related_change = False
                    list_value = extract_stat(each_change)
                    past_value = list_value[0]
                    current_value = list_value[1]
                else:
                    if is_past_value_to_add:
                        intelligence_gain_dict[version] = past_value_to_add
            
            if no_related_change:
                list_versions_empty.append(version)
            else:
                intelligence_gain_dict[version] = current_value
                for each_version in list_versions_empty:
                    intelligence_gain_dict[each_version] = current_value
                list_versions_empty = list()
                past_value_to_add = past_value
                is_past_value_to_add = True
        
        for key in intelligence_gain_dict:
            if intelligence_gain_dict[key] == -100:
                current_stat = get_current_stat(hero_name, 'int_gain')
                use_current_stat = True
                break
        
        if use_current_stat:
            for key in intelligence_gain_dict:
                intelligence_gain_dict[key] = current_stat
            use_current_stat = False

        # base health       
        list_versions_empty = list()
        past_value_to_add = 0
        is_past_value_to_add = False
        
        for each_key in version_changes_dict:
            version = each_key
            changes = version_changes_dict[each_key]
            changes_list = changes.split(',')
            no_related_change = True
            for each_change in changes_list:
                if "base health from" in each_change and "/" not in each_change:
                    no_related_change = False
                    list_value = extract_stat(each_change)
                    past_value = list_value[0]
                    current_value = list_value[1]
                else:
                    if is_past_value_to_add:
                        base_health_dict[version] = past_value_to_add
            
            if no_related_change:
                list_versions_empty.append(version)
            else:
                base_health_dict[version] = current_value
                for each_version in list_versions_empty:
                    base_health_dict[each_version] = current_value
                list_versions_empty = list()
                past_value_to_add = past_value
                is_past_value_to_add = True
        
        for key in base_health_dict:
            if base_health_dict[key] == -100:
                current_stat = get_current_stat(hero_name, 'base_health')
                use_current_stat = True
                break
        
        if use_current_stat:
            for key in base_health_dict:
                base_health_dict[key] = current_stat
            use_current_stat = False
            
        # base health regeneration     
        list_versions_empty = list()
        past_value_to_add = 0
        is_past_value_to_add = False
        
        for each_key in version_changes_dict:
            version = each_key
            changes = version_changes_dict[each_key]
            changes_list = changes.split(',')
            no_related_change = True
            for each_change in changes_list:
                if "base health regeneration from" in each_change:
                    no_related_change = False
                    list_value = extract_stat(each_change)
                    past_value = list_value[0]
                    current_value = list_value[1]
                else:
                    if is_past_value_to_add:
                        base_health_regeneration_dict[version] = past_value_to_add
            
            if no_related_change:
                list_versions_empty.append(version)
            else:
                base_health_regeneration_dict[version] = current_value
                for each_version in list_versions_empty:
                    base_health_regeneration_dict[each_version] = current_value
                list_versions_empty = list()
                past_value_to_add = past_value
                is_past_value_to_add = True
        
        for key in base_health_regeneration_dict:
            if base_health_regeneration_dict[key] == -100:
                current_stat = get_current_stat(hero_name, 'base_health_regen')
                use_current_stat = True
                break
        
        if use_current_stat:
            for key in base_health_regeneration_dict:
                base_health_regeneration_dict[key] = current_stat
            use_current_stat = False

        # movement speed    
        list_versions_empty = list()
        past_value_to_add = 0
        is_past_value_to_add = False
        
        for each_key in version_changes_dict:
            version = each_key
            changes = version_changes_dict[each_key]
            changes_list = changes.split(',')
            no_related_change = True
            for each_change in changes_list:
                if "movement speed from" in each_change and "/" not in each_change:
                    #print(each_change)
                    no_related_change = False
                    list_value = extract_stat(each_change)
                    past_value = list_value[0]
                    current_value = list_value[1]
                else:
                    if is_past_value_to_add:
                        move_speed_dict[version] = past_value_to_add
            
            if no_related_change:
                list_versions_empty.append(version)
            else:
                move_speed_dict[version] = current_value
                for each_version in list_versions_empty:
                    move_speed_dict[each_version] = current_value
                list_versions_empty = list()
                past_value_to_add = past_value
                is_past_value_to_add = True
        
        for key in move_speed_dict:
            if move_speed_dict[key] == -100:
                current_stat = get_current_stat(hero_name, 'base_health_regen')
                use_current_stat = True
                break
        
        if use_current_stat:
            for key in move_speed_dict:
                move_speed_dict[key] = current_stat
            use_current_stat = False

    print(len(base_strength_dict))
    print(len(base_agility_dict))
    print(len(base_intelligence_dict))
    print(len(strength_gain_dict))
    print(len(agility_gain_dict))
    print(len(intelligence_gain_dict))
    print(len(base_health_dict))
    print(len(base_health_regeneration_dict))
    print(len(move_speed_dict))

    print("number of versions: " , len(list_of_versions))
    for each_version in list_of_versions:
        list_to_add = list()
        
        base_strength = base_strength_dict[each_version]
        base_agility = base_agility_dict[each_version]
        base_intelligence = base_intelligence_dict[each_version]
        
        strength_gain = strength_gain_dict[each_version]
        agility_gain = agility_gain_dict[each_version]
        intelligence_gain = intelligence_gain_dict[each_version]
        
        base_health = base_health_dict[each_version]
        base_health_regeneration = base_health_regeneration_dict[each_version]
        move_speed = move_speed_dict[each_version]
        
        list_to_add.append(each_version)
        list_to_add.append(base_strength)
        list_to_add.append(base_agility)
        list_to_add.append(base_intelligence)
        list_to_add.append(strength_gain)
        list_to_add.append(agility_gain)
        list_to_add.append(intelligence_gain)
        list_to_add.append(base_health)
        list_to_add.append(base_health_regeneration)
        list_to_add.append(move_speed)
        
        hero_historical_stats_df.loc[index_df] = list_to_add
        index_df += 1
        hero_historical_stats_df.to_csv(hero_historical_stats_dir + hero_name + '_historical_stats.csv')
# Out:
# Abaddon_changelog_dict.csv
# Abaddon
# 58
# 58
# 58
# 58
# 58
# 58
# 58
# 58
# 58
# number of versions:  58
# Alchemist_changelog_dict.csv
# Alchemist
# 64
# 64
# 64
# 64
# 64
# 64
# 64
# 64
# 64
# number of versions:  64
# Ancient Apparition_changelog_dict.csv
# Ancient Apparition
# 42
# 42
# 42
# 42
# 42
# 42
# 42
# 42
# 42
# number of versions:  42
# Anti-Mage_changelog_dict.csv
# Anti-Mage
# 72
# 72
# 72
# 72
# 72
# 72
# 72
# 72
# 72
# number of versions:  72
# Arc Warden_changelog_dict.csv
# Arc Warden
# 34
# 34
# 34
# 34
# 34
# 34
# 34
# 34
# 34
# number of versions:  34
# Axe_changelog_dict.csv
# Axe
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# number of versions:  61
# Bane_changelog_dict.csv
# Bane
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# number of versions:  55
# Batrider_changelog_dict.csv
# Batrider
# 43
# 43
# 43
# 43
# 43
# 43
# 43
# 43
# 43
# number of versions:  43
# Beastmaster_changelog_dict.csv
# Beastmaster
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# number of versions:  61
# Bloodseeker_changelog_dict.csv
# Bloodseeker
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# number of versions:  70
# Bounty Hunter_changelog_dict.csv
# Bounty Hunter
# 89
# 89
# 89
# 89
# 89
# 89
# 89
# 89
# 89
# number of versions:  89
# Brewmaster_changelog_dict.csv
# Brewmaster
# 76
# 76
# 76
# 76
# 76
# 76
# 76
# 76
# 76
# number of versions:  76
# Bristleback_changelog_dict.csv
# Bristleback
# 58
# 58
# 58
# 58
# 58
# 58
# 58
# 58
# 58
# number of versions:  58
# Broodmother_changelog_dict.csv
# Broodmother
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# number of versions:  70
# Centaur Warrunner_changelog_dict.csv
# Centaur Warrunner
# 65
# 65
# 65
# 65
# 65
# 65
# 65
# 65
# 65
# number of versions:  65
# Chaos Knight_changelog_dict.csv
# Chaos Knight
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# number of versions:  82
# Chen_changelog_dict.csv
# Chen
# 86
# 86
# 86
# 86
# 86
# 86
# 86
# 86
# 86
# number of versions:  86
# Clinkz_changelog_dict.csv
# Clinkz
# 83
# 83
# 83
# 83
# 83
# 83
# 83
# 83
# 83
# number of versions:  83
# Clockwerk_changelog_dict.csv
# Clockwerk
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# number of versions:  49
# Crystal Maiden_changelog_dict.csv
# Crystal Maiden
# 86
# 86
# 86
# 86
# 86
# 86
# 86
# 86
# 86
# number of versions:  86
# Dark Seer_changelog_dict.csv
# Dark Seer
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# number of versions:  55
# Dark Willow_changelog_dict.csv
# Dark Willow
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# number of versions:  23
# Dazzle_changelog_dict.csv
# Dazzle
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# number of versions:  59
# Death Prophet_changelog_dict.csv
# Death Prophet
# 79
# 79
# 79
# 79
# 79
# 79
# 79
# 79
# 79
# number of versions:  79
# Disruptor_changelog_dict.csv
# Disruptor
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# number of versions:  32
# Doom_changelog_dict.csv
# Doom
# 93
# 93
# 93
# 93
# 93
# 93
# 93
# 93
# 93
# number of versions:  93
# Dragon Knight_changelog_dict.csv
# Dragon Knight
# 72
# 72
# 72
# 72
# 72
# 72
# 72
# 72
# 72
# number of versions:  72
# Drow Ranger_changelog_dict.csv
# Drow Ranger
# 89
# 89
# 89
# 89
# 89
# 89
# 89
# 89
# 89
# number of versions:  89
# Earth Spirit_changelog_dict.csv
# Earth Spirit
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# number of versions:  31
# Earthshaker_changelog_dict.csv
# Earthshaker
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# number of versions:  54
# Elder Titan_changelog_dict.csv
# Elder Titan
# 43
# 43
# 43
# 43
# 43
# 43
# 43
# 43
# 43
# number of versions:  43
# Ember Spirit_changelog_dict.csv
# Ember Spirit
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# number of versions:  40
# Enchantress_changelog_dict.csv
# Enchantress
# 77
# 77
# 77
# 77
# 77
# 77
# 77
# 77
# 77
# number of versions:  77
# Enigma_changelog_dict.csv
# Enigma
# 62
# 62
# 62
# 62
# 62
# 62
# 62
# 62
# 62
# number of versions:  62
# Faceless Void_changelog_dict.csv
# Faceless Void
# 87
# 87
# 87
# 87
# 87
# 87
# 87
# 87
# 87
# number of versions:  87
# Grimstroke_changelog_dict.csv
# Grimstroke
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# number of versions:  17
# Gyrocopter_changelog_dict.csv
# Gyrocopter
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# number of versions:  45
# Huskar_changelog_dict.csv
# Huskar
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# number of versions:  50
# Invoker_changelog_dict.csv
# Invoker
# 58
# 58
# 58
# 58
# 58
# 58
# 58
# 58
# 58
# number of versions:  58
# Io_changelog_dict.csv
# Io
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# number of versions:  45
# Jakiro_changelog_dict.csv
# Jakiro
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# number of versions:  51
# Juggernaut_changelog_dict.csv
# Juggernaut
# 83
# 83
# 83
# 83
# 83
# 83
# 83
# 83
# 83
# number of versions:  83
# Keeper of the Light_changelog_dict.csv
# Keeper of the Light
# 79
# 79
# 79
# 79
# 79
# 79
# 79
# 79
# 79
# number of versions:  79
# Kunkka_changelog_dict.csv
# Kunkka
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# number of versions:  49
# Legion Commander_changelog_dict.csv
# Legion Commander
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# number of versions:  35
# Leshrac_changelog_dict.csv
# Leshrac
# 78
# 78
# 78
# 78
# 78
# 78
# 78
# 78
# 78
# number of versions:  78
# Lich_changelog_dict.csv
# Lich
# 90
# 90
# 90
# 90
# 90
# 90
# 90
# 90
# 90
# number of versions:  90
# Lifestealer_changelog_dict.csv
# Lifestealer
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# number of versions:  69
# Lina_changelog_dict.csv
# Lina
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# number of versions:  70
# Lion_changelog_dict.csv
# Lion
# 65
# 65
# 65
# 65
# 65
# 65
# 65
# 65
# 65
# number of versions:  65
# Lone Druid_changelog_dict.csv
# Lone Druid
# 66
# 66
# 66
# 66
# 66
# 66
# 66
# 66
# 66
# number of versions:  66
# Luna_changelog_dict.csv
# Luna
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# number of versions:  82
# Lycan_changelog_dict.csv
# Lycan
# 87
# 87
# 87
# 87
# 87
# 87
# 87
# 87
# 87
# number of versions:  87
# Magnus_changelog_dict.csv
# Magnus
# 87
# 87
# 87
# 87
# 87
# 87
# 87
# 87
# 87
# number of versions:  87
# Mars_changelog_dict.csv
# Mars
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# number of versions:  10
# Medusa_changelog_dict.csv
# Medusa
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# number of versions:  80
# Meepo_changelog_dict.csv
# Meepo
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# number of versions:  55
# Mirana_changelog_dict.csv
# Mirana
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# number of versions:  54
# Monkey King_changelog_dict.csv
# Monkey King
# 26
# 26
# 26
# 26
# 26
# 26
# 26
# 26
# 26
# number of versions:  26
# Morphling_changelog_dict.csv
# Morphling
# 91
# 91
# 91
# 91
# 91
# 91
# 91
# 91
# 91
# number of versions:  91
# Naga Siren_changelog_dict.csv
# Naga Siren
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# number of versions:  60
# Nature's Prophet_changelog_dict.csv
# Nature's Prophet
# 88
# 88
# 88
# 88
# 88
# 88
# 88
# 88
# 88
# number of versions:  88
# Necrophos_changelog_dict.csv
# Necrophos
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# number of versions:  68
# Night Stalker_changelog_dict.csv
# Night Stalker
# 73
# 73
# 73
# 73
# 73
# 73
# 73
# 73
# 73
# number of versions:  73
# Nyx Assassin_changelog_dict.csv
# Nyx Assassin
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# number of versions:  70
# Ogre Magi_changelog_dict.csv
# Ogre Magi
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# number of versions:  69
# Omniknight_changelog_dict.csv
# Omniknight
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# number of versions:  81
# Oracle_changelog_dict.csv
# Oracle
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# number of versions:  35
# Outworld Devourer_changelog_dict.csv
# Outworld Devourer
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# number of versions:  69
# Pangolier_changelog_dict.csv
# Pangolier
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# number of versions:  17
# Phantom Assassin_changelog_dict.csv
# Phantom Assassin
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# number of versions:  80
# Phantom Lancer_changelog_dict.csv
# Phantom Lancer
# 62
# 62
# 62
# 62
# 62
# 62
# 62
# 62
# 62
# number of versions:  62
# Phoenix_changelog_dict.csv
# Phoenix
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# number of versions:  49
# Puck_changelog_dict.csv
# Puck
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# number of versions:  55
# Pudge_changelog_dict.csv
# Pudge
# 57
# 57
# 57
# 57
# 57
# 57
# 57
# 57
# 57
# number of versions:  57
# Pugna_changelog_dict.csv
# Pugna
# 64
# 64
# 64
# 64
# 64
# 64
# 64
# 64
# 64
# number of versions:  64
# Queen of Pain_changelog_dict.csv
# Queen of Pain
# 66
# 66
# 66
# 66
# 66
# 66
# 66
# 66
# 66
# number of versions:  66
# Razor_changelog_dict.csv
# Razor
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# number of versions:  69
# Riki_changelog_dict.csv
# Riki
# 75
# 75
# 75
# 75
# 75
# 75
# 75
# 75
# 75
# number of versions:  75
# Rubick_changelog_dict.csv
# Rubick
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# number of versions:  32
# Sand King_changelog_dict.csv
# Sand King
# 72
# 72
# 72
# 72
# 72
# 72
# 72
# 72
# 72
# number of versions:  72
# Shadow Demon_changelog_dict.csv
# Shadow Demon
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# number of versions:  46
# Shadow Fiend_changelog_dict.csv
# Shadow Fiend
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# number of versions:  46
# Shadow Shaman_changelog_dict.csv
# Shadow Shaman
# 65
# 65
# 65
# 65
# 65
# 65
# 65
# 65
# 65
# number of versions:  65
# Silencer_changelog_dict.csv
# Silencer
# 63
# 63
# 63
# 63
# 63
# 63
# 63
# 63
# 63
# number of versions:  63
# Skywrath Mage_changelog_dict.csv
# Skywrath Mage
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# number of versions:  40
# Slardar_changelog_dict.csv
# Slardar
# 76
# 76
# 76
# 76
# 76
# 76
# 76
# 76
# 76
# number of versions:  76
# Slark_changelog_dict.csv
# Slark
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# number of versions:  51
# Snapfire_changelog_dict.csv
# Snapfire
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# number of versions:  10
# Sniper_changelog_dict.csv
# Sniper
# 78
# 78
# 78
# 78
# 78
# 78
# 78
# 78
# 78
# number of versions:  78
# Spectre_changelog_dict.csv
# Spectre
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# number of versions:  61
# Spirit Breaker_changelog_dict.csv
# Spirit Breaker
# 71
# 71
# 71
# 71
# 71
# 71
# 71
# 71
# 71
# number of versions:  71
# Storm Spirit_changelog_dict.csv
# Storm Spirit
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# number of versions:  41
# Sven_changelog_dict.csv
# Sven
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# number of versions:  80
# Techies_changelog_dict.csv
# Techies
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# number of versions:  70
# Templar Assassin_changelog_dict.csv
# Templar Assassin
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# number of versions:  45
# Terrorblade_changelog_dict.csv
# Terrorblade
# 84
# 84
# 84
# 84
# 84
# 84
# 84
# 84
# 84
# number of versions:  84
# Tidehunter_changelog_dict.csv
# Tidehunter
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# number of versions:  52
# Timbersaw_changelog_dict.csv
# Timbersaw
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# number of versions:  35
# Tinker_changelog_dict.csv
# Tinker
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# number of versions:  53
# Tiny_changelog_dict.csv
# Tiny
# 79
# 79
# 79
# 79
# 79
# 79
# 79
# 79
# 79
# number of versions:  79
# Treant Protector_changelog_dict.csv
# Treant Protector
# 78
# 78
# 78
# 78
# 78
# 78
# 78
# 78
# 78
# number of versions:  78
# Troll Warlord_changelog_dict.csv
# Troll Warlord
# 63
# 63
# 63
# 63
# 63
# 63
# 63
# 63
# 63
# number of versions:  63
# Tusk_changelog_dict.csv
# Tusk
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# number of versions:  45
# Underlord_changelog_dict.csv
# Underlord
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# number of versions:  41
# Undying_changelog_dict.csv
# Undying
# 64
# 64
# 64
# 64
# 64
# 64
# 64
# 64
# 64
# number of versions:  64
# Ursa_changelog_dict.csv
# Ursa
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# number of versions:  67
# Vengeful Spirit_changelog_dict.csv
# Vengeful Spirit
# 79
# 79
# 79
# 79
# 79
# 79
# 79
# 79
# 79
# number of versions:  79
# Venomancer_changelog_dict.csv
# Venomancer
# 79
# 79
# 79
# 79
# 79
# 79
# 79
# 79
# 79
# number of versions:  79
# Viper_changelog_dict.csv
# Viper
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# number of versions:  70
# Visage_changelog_dict.csv
# Visage
# 94
# 94
# 94
# 94
# 94
# 94
# 94
# 94
# 94
# number of versions:  94
# Void Spirit_changelog_dict.csv
# Void Spirit
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# number of versions:  10
# Warlock_changelog_dict.csv
# Warlock
# 62
# 62
# 62
# 62
# 62
# 62
# 62
# 62
# 62
# number of versions:  62
# Weaver_changelog_dict.csv
# Weaver
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# number of versions:  69
# Windranger_changelog_dict.csv
# Windranger
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# number of versions:  45
# Winter Wyvern_changelog_dict.csv
# Winter Wyvern
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# number of versions:  40
# Witch Doctor_changelog_dict.csv
# Witch Doctor
# 44
# 44
# 44
# 44
# 44
# 44
# 44
# 44
# 44
# number of versions:  44
# Wraith King_changelog_dict.csv
# Wraith King
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# number of versions:  67
# Zeus_changelog_dict.csv
# Zeus
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# number of versions:  85
